# %% [markdown]
# # Random Forest Module
#
# talk about ensembles
#
# talk about bootstrap
#
# talk about decreased variance

# %%
# ! Note: run this cell first to import necessary packages
import sys
from pathlib import Path

curr = Path.cwd()
root = str(curr.parent if curr.name == "notebooks" else curr)

if root not in sys.path:
    sys.path.insert(0, root)
